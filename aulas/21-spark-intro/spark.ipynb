# %% [markdown]
# # Apache Spark

# %% [markdown]
# ## Instalando o ambiente
#
# ### Opção 1 - Docker

# %% [markdown]
# O jeito mais simples de começar a trabalhar com Spark é instalar um container com tudo pronto! No site https://hub.docker.com/r/jupyter/pyspark-notebook vemos uma imagem Docker que já vem com `pyspark` e `jupyter lab`. Instale a imagem com o comando:
#
# ```bash
# docker pull jupyter/pyspark-notebook
# ```

# %% [markdown]
# Vamos iniciar o ambiente de trabalho com o comando `docker run`. Para isso precisamos tomar alguns cuidados:
#
# 1) Temos que mapear nosso diretorio local de trabalho para um diretório interno do container, de modo que alterações feitas dentro do container (nesta pasta escolhida) sejam gravadas no nosso diretorio local. No container temos um usuário padrão com *username* `jovyan`. No *homedir* desse usuario temos uma pasta vazia `work`, que vai servir como local de mapeamento do nosso diretorio local de trabalho. Podemos então fazer esse mapeamendo com a opção `-v` do comando `docker run` da seguinte forma:
#
# ```bash
# -v <diretorio>:/home/jovyan/work
# ```
#
# onde `<diretorio>` representa seu diretorio local de trabalho.
#
# 2) Para acessar o `jupyter notebook` e o *dashboard* do Spark a partir do nosso *browser* favorito temos que abrir algumas portas do container com a opção `-p`. As portas são `8888` (para o próprio `jupyter notebook`) e `4040` (para o *dashboard* do Spark). Ou seja, adicionaremos às opções do `docker run`o seguinte:
#
# ```bash
# -p 8888:8888 -p 4040:4040
# ```
#
# Desta forma, ao acessar `localhost:8888` na nossa máquina, estaremos acessando o servidor Jupyter na porta 8888 interna do container.
#
# 3) Vamos iniciar o container no modo interativo, e vamos especificar que o container deve ser encerrado ao fechar o servidor Jupyter. Faremos isso com as opções `-it` e `-rm`
#
# Antes de executar, garanta que as portas 4040 e 8888 estão livres (sem jupyter já executando) ou altere o comando. Ainda, esteja na pasta da aula ao executar, assim apenas ela será exposta ao container.
#
# Portanto, o comando completo que eu uso na minha máquina Linux para iniciar o container é:

# %% [markdown]
# ```bash
# docker run \
#     -it \
#     --rm \
#     -p 8888:8888 \
#     -p 4040:4040 \
#     -v "`pwd`":/home/jovyan/work \
#     jupyter/pyspark-notebook
#
# ```

# %% [markdown]
# Se estiver no Windows estes comandos, utilize:
#
# - No Powershell: `docker run -it --rm -p 8888:8888 -p 4040:4040 -v ${PWD}:/home/jovyan/work jupyter/pyspark-notebook`
#
# - No Prompt de comando: `docker run -it --rm -p 8888:8888 -p 4040:4040 -v %cd%:/home/jovyan/work jupyter/pyspark-notebook`

# %% [markdown]
# Para facilitar a vida eu coloco esse comando em um arquivo `inicia.sh`. Engenheiros, façam do jeito que preferirem!
#
# Agora abra esse notebook lá no container utilizando o link **com o token** que é exibido ao executar o comando!
#
# **Importante:** Se você já estiver visualizando esse notebook via Jupyter, pode ser necessário encerrar o processo para que o comando acima funcione.

# %% [markdown]
# Vamos agora configurar o insperautograder para que funcione dentro do container do Docker. Primeiro, instale e importe a biblioteca:

# %%
# !pip install git+https://github.com/macielcalebe/insperautograding.git

import insperautograder.jupyter as ia
from dotenv import load_dotenv
# Out:
# Collecting git+https://github.com/macielcalebe/insperautograding.git
#   Cloning https://github.com/macielcalebe/insperautograding.git to /tmp/pip-req-build-yalyimdn
#   Running command git clone --filter=blob:none --quiet https://github.com/macielcalebe/insperautograding.git /tmp/pip-req-build-yalyimdn
#   Resolved https://github.com/macielcalebe/insperautograding.git to commit 49f1176548d7560b38d0314e1115f93467141893
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (from insperautograder==0.4.0) (1.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from insperautograder==0.4.0) (2.31.0)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.11/site-packages (from insperautograder==0.4.0) (8.16.1)
# Requirement already satisfied: ipywidgets<=7.8.5 in /opt/conda/lib/python3.11/site-packages (from insperautograder==0.4.0) (7.8.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from ipywidgets<=7.8.5->insperautograder==0.4.0) (0.1.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.11/site-packages (from ipywidgets<=7.8.5->insperautograder==0.4.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.11/site-packages (from ipywidgets<=7.8.5->insperautograder==0.4.0) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=3.6.10 in /opt/conda/lib/python3.11/site-packages (from ipywidgets<=7.8.5->insperautograder==0.4.0) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from ipywidgets<=7.8.5->insperautograder==0.4.0) (1.1.11)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython->insperautograder==0.4.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->insperautograder==0.4.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->insperautograder==0.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->insperautograder==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->insperautograder==0.4.0) (2023.7.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython->insperautograder==0.4.0) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython->insperautograder==0.4.0) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->insperautograder==0.4.0) (0.2.8)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.11/site-packages (from widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (7.0.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->insperautograder==0.4.0) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->insperautograder==0.4.0) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->insperautograder==0.4.0) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython->insperautograder==0.4.0) (1.16.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.8.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/conda/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /opt/conda/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (4.0.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/conda/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (6.3.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (4.0.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (23.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (5.4.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (7.9.2)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (5.9.2)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (7.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (23.2)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.17.1)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (6.25.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (4.19.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (3.11.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.18.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.8.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.5.8)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (5.9.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (0.5.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<=7.8.5->insperautograder==0.4.0) (2.8.19.14)

# %% [markdown]
# Copie o arquivo .env para dentro da pasta que está vinculada ao container e veja se está funcionando:

# %%
load_dotenv()
ia.tasks()
# Out:
# |    | Atividade            | De                  | Até                 | Conta como ATV?   | % Nota Atraso   |
# |---:|:---------------------|:--------------------|:--------------------|:------------------|:----------------|
# |  0 | newborn              | 2026-02-09 00:00:00 | 2026-05-30 00:00:00 | Não               | 0%              |
# |  1 | select01             | 2026-02-12 16:00:00 | 2026-02-22 23:59:59 | Sim               | 25%             |
# |  2 | ddl                  | 2026-02-26 12:00:00 | 2026-03-05 23:59:59 | Sim               | 25%             |
# |  3 | dml                  | 2026-03-02 14:15:00 | 2026-03-08 23:59:59 | Sim               | 25%             |
# |  4 | agg_join             | 2026-03-05 14:15:00 | 2026-03-12 23:59:59 | Sim               | 25%             |
# |  5 | group_having         | 2026-03-09 14:15:00 | 2026-03-15 23:59:59 | Sim               | 25%             |
# |  6 | views                | 2026-03-12 14:15:00 | 2026-03-19 23:59:59 | Sim               | 25%             |
# |  7 | sql_review1          | 2026-03-16 14:15:00 | 2026-03-22 23:59:59 | Sim               | 25%             |
# |  8 | ai_md_23_2           | 2026-03-22 07:00:00 | 2026-03-25 06:00:00 | Sim               | 25%             |
# |  9 | ai_md_23_1           | 2026-03-22 07:00:00 | 2026-03-25 06:00:00 | Não               | 25%             |
# | 10 | ai_md_26_1           | 2026-03-25 07:30:00 | 2026-03-25 09:30:00 | Não               | 0%              |
# | 11 | permissions          | 2026-04-06 13:30:00 | 2026-04-12 23:59:59 | Sim               | 25%             |
# | 12 | desafio_normalizacao | 2026-04-09 13:30:00 | 2026-04-30 23:59:59 | Não               | 0%              |
# | 13 | triggers             | 2026-04-27 13:30:00 | 2026-05-05 23:59:59 | Sim               | 25%             |
# | 14 | functional           | 2026-05-04 13:30:00 | 2026-05-10 23:59:59 | Sim               | 25%             |
# | 15 | spark                | 2026-05-07 13:30:00 | 2026-05-14 23:59:59 | Sim               | 25%             |

# %%
ia.grades()
# Out:
# |     | Atividade            | Exercício   |   Peso |   Nota |   Nota Sem Atraso |   Nota Com Atraso |
# |----:|:---------------------|:------------|-------:|-------:|------------------:|------------------:|
# |   0 | newborn              | ex01        |      1 |     10 |                10 |                 0 |
# |   1 | select01             | ex01        |      1 |     10 |                10 |                 0 |
# |   2 | select01             | ex02        |      1 |     10 |                10 |                 0 |
# |   3 | select01             | ex03        |      1 |     10 |                10 |                 0 |
# |   4 | select01             | ex04        |      1 |     10 |                10 |                 0 |
# |   5 | select01             | ex05        |      1 |     10 |                10 |                 0 |
# |   6 | ddl                  | ex02        |      1 |     10 |                10 |                 0 |
# |   7 | ddl                  | ex03        |      1 |     10 |                10 |                 0 |
# |   8 | ddl                  | ex04        |      1 |     10 |                10 |                 0 |
# |   9 | ddl                  | ex05        |      1 |     10 |                10 |                 0 |
# |  10 | ddl                  | ex06        |      1 |     10 |                10 |                 0 |
# |  11 | ddl                  | ex07        |      1 |     10 |                10 |                 0 |
# |  12 | ddl                  | ex09        |      1 |     10 |                10 |                 0 |
# |  13 | ddl                  | ex10        |      1 |     10 |                10 |                 0 |
# |  14 | ddl                  | ex11        |      1 |     10 |                10 |                 0 |
# |  15 | dml                  | ex01        |      1 |     10 |                10 |                 0 |
# |  16 | dml                  | ex02        |      1 |     10 |                10 |                 0 |
# |  17 | dml                  | ex03        |      1 |     10 |                10 |                 0 |
# |  18 | dml                  | ex04        |      1 |     10 |                10 |                 0 |
# |  19 | dml                  | ex05        |      1 |     10 |                10 |                 0 |
# |  20 | dml                  | ex06        |      1 |     10 |                10 |                 0 |
# |  21 | agg_join             | ex01        |      1 |     10 |                10 |                 0 |
# |  22 | agg_join             | ex02        |      1 |     10 |                10 |                 0 |
# |  23 | agg_join             | ex03        |      1 |     10 |                10 |                 0 |
# |  24 | agg_join             | ex04        |      1 |     10 |                10 |                 0 |
# |  25 | agg_join             | ex05        |      1 |     10 |                10 |                 0 |
# |  26 | agg_join             | ex06        |      1 |     10 |                10 |                 0 |
# |  27 | group_having         | ex01        |      1 |     10 |                10 |                 0 |
# |  28 | group_having         | ex02        |      4 |     10 |                10 |                 0 |
# |  29 | group_having         | ex03        |      4 |     10 |                10 |                 0 |
# |  30 | group_having         | ex04        |      4 |     10 |                10 |                 0 |
# |  31 | group_having         | ex05        |      4 |     10 |                10 |                 0 |
# |  32 | group_having         | ex06        |      8 |     10 |                10 |                 0 |
# |  33 | group_having         | ex07        |      6 |     10 |                10 |                 0 |
# |  34 | group_having         | ex08        |      6 |     10 |                10 |                 0 |
# |  35 | group_having         | ex09        |     12 |     10 |                10 |                 0 |
# |  36 | group_having         | ex10        |     10 |     10 |                10 |                 0 |
# |  37 | group_having         | ex11        |     10 |     10 |                10 |                 0 |
# |  38 | group_having         | ex12        |      6 |     10 |                10 |                 0 |
# |  39 | group_having         | ex13        |     12 |     10 |                10 |                 0 |
# |  40 | views                | ex01        |      1 |     10 |                10 |                 0 |
# |  41 | views                | ex02        |      1 |     10 |                10 |                 0 |
# |  42 | views                | ex03        |      1 |     10 |                10 |                 0 |
# |  43 | views                | ex04        |      1 |     10 |                10 |                 0 |
# |  44 | views                | ex05        |      1 |     10 |                10 |                 0 |
# |  45 | views                | ex06        |      1 |     10 |                10 |                 0 |
# |  46 | views                | ex07        |      1 |     10 |                10 |                 0 |
# |  47 | views                | ex08        |      1 |     10 |                10 |                 0 |
# |  48 | views                | ex09        |      1 |     10 |                10 |                 0 |
# |  49 | views                | ex10        |      1 |     10 |                10 |                 0 |
# |  50 | views                | ex11        |      1 |     10 |                10 |                 0 |
# |  51 | views                | ex12        |      1 |     10 |                10 |                 0 |
# |  52 | sql_review1          | ex01        |      1 |     10 |                10 |                 0 |
# |  53 | sql_review1          | ex02        |      1 |     10 |                10 |                 0 |
# |  54 | sql_review1          | ex03        |      1 |     10 |                10 |                 0 |
# |  55 | sql_review1          | ex04        |      1 |     10 |                10 |                 0 |
# |  56 | sql_review1          | ex05        |      1 |     10 |                10 |                 0 |
# |  57 | sql_review1          | ex06        |      1 |     10 |                10 |                 0 |
# |  58 | sql_review1          | ex07        |      2 |     10 |                10 |                 0 |
# |  59 | sql_review1          | ex08        |      3 |     10 |                10 |                 0 |
# |  60 | sql_review1          | ex09        |      2 |     10 |                10 |                 0 |
# |  61 | sql_review1          | ex10        |      1 |     10 |                10 |                 0 |
# |  62 | sql_review1          | ex11        |      3 |     10 |                10 |                 0 |
# |  63 | sql_review1          | ex12        |      3 |     10 |                10 |                 0 |
# |  64 | ai_md_23_2           | ex00        |      0 |     10 |                10 |                 0 |
# |  65 | ai_md_23_2           | ex01        |      2 |     10 |                10 |                 0 |
# |  66 | ai_md_23_1           | ex01        |      1 |      0 |                 0 |                 0 |
# |  67 | ai_md_23_1           | ex02        |      1 |      0 |                 0 |                 0 |
# |  68 | ai_md_23_2           | ex02        |      3 |     10 |                10 |                 0 |
# |  69 | ai_md_23_1           | ex03        |      1 |      0 |                 0 |                 0 |
# |  70 | ai_md_23_2           | ex03        |      3 |     10 |                10 |                 0 |
# |  71 | ai_md_23_1           | ex04        |      1 |      0 |                 0 |                 0 |
# |  72 | ai_md_23_2           | ex04        |      2 |     10 |                10 |                 0 |
# |  73 | ai_md_23_2           | ex05        |      3 |     10 |                10 |                 0 |
# |  74 | ai_md_23_1           | ex05        |      1 |      0 |                 0 |                 0 |
# |  75 | ai_md_23_1           | ex06        |      1 |      0 |                 0 |                 0 |
# |  76 | ai_md_23_2           | ex06        |      3 |     10 |                10 |                 0 |
# |  77 | ai_md_26_1           | ex01        |      2 |     10 |                10 |                 0 |
# |  78 | ai_md_26_1           | ex02        |      3 |     10 |                10 |                 0 |
# |  79 | ai_md_26_1           | ex03        |      3 |     10 |                10 |                 0 |
# |  80 | ai_md_26_1           | ex04        |      3 |     10 |                10 |                 0 |
# |  81 | ai_md_26_1           | ex05        |      2 |      0 |                 0 |                 0 |
# |  82 | ai_md_26_1           | ex06        |      3 |     10 |                10 |                 0 |
# |  83 | permissions          | ex01        |      1 |     10 |                10 |                 0 |
# |  84 | permissions          | ex02        |      1 |     10 |                10 |                 0 |
# |  85 | permissions          | ex03        |      1 |     10 |                10 |                 0 |
# |  86 | permissions          | ex04        |      1 |     10 |                10 |                 0 |
# |  87 | permissions          | ex05        |      1 |     10 |                10 |                 0 |
# |  88 | permissions          | ex06        |      1 |     10 |                10 |                 0 |
# |  89 | permissions          | ex07        |      1 |     10 |                10 |                 0 |
# |  90 | permissions          | ex08        |      1 |     10 |                10 |                 0 |
# |  91 | permissions          | ex09        |      1 |     10 |                10 |                 0 |
# |  92 | permissions          | ex10        |      1 |     10 |                10 |                 0 |
# |  93 | permissions          | ex11        |      1 |     10 |                10 |                 0 |
# |  94 | permissions          | ex12        |      1 |     10 |                10 |                 0 |
# |  95 | permissions          | ex13b       |      1 |     10 |                10 |                 0 |
# |  96 | desafio_normalizacao | ex01        |      1 |     10 |                10 |                 0 |
# |  97 | desafio_normalizacao | ex02        |      1 |     10 |                10 |                 0 |
# |  98 | desafio_normalizacao | ex03        |      1 |      0 |                 0 |                 0 |
# |  99 | desafio_normalizacao | ex04        |      1 |      0 |                 0 |                 0 |
# | 100 | desafio_normalizacao | ex05        |      1 |      0 |                 0 |                 0 |
# | 101 | triggers             | ex01        |      1 |     10 |                10 |                 0 |
# | 102 | triggers             | ex02        |      1 |     10 |                10 |                 0 |
# | 103 | triggers             | ex04        |      1 |     10 |                10 |                 0 |
# | 104 | triggers             | ex05        |      1 |     10 |                10 |                 0 |
# | 105 | triggers             | ex06        |      1 |     10 |                10 |                 0 |
# | 106 | triggers             | ex07        |      1 |     10 |                10 |                 0 |
# | 107 | triggers             | ex08        |      1 |     10 |                10 |                 0 |
# | 108 | triggers             | ex09        |      1 |     10 |                10 |                 0 |
# | 109 | functional           | ex01        |      1 |     10 |                10 |                 0 |
# | 110 | functional           | ex02        |      1 |     10 |                10 |                 0 |
# | 111 | functional           | ex03        |      1 |     10 |                10 |                 0 |
# | 112 | functional           | ex04        |      1 |     10 |                10 |                 0 |
# | 113 | functional           | ex05        |      1 |     10 |                10 |                 0 |
# | 114 | functional           | ex06        |      1 |     10 |                10 |                 0 |
# | 115 | functional           | ex07        |      1 |     10 |                10 |                 0 |
# | 116 | spark                | desafio1    |      1 |      0 |                 0 |                 0 |
# | 117 | spark                | desafio2    |      1 |      0 |                 0 |                 0 |
# | 118 | spark                | ex01        |      1 |     10 |                10 |                 0 |
# | 119 | spark                | ex02        |      1 |     10 |                10 |                 0 |
# | 120 | spark                | ex03        |      1 |     10 |                10 |                 0 |
# | 121 | spark                | ex04        |      1 |     10 |                10 |                 0 |
# | 122 | spark                | ex05        |      1 |     10 |                10 |                 0 |

# %% [markdown]
# ### Opção 2 - Instalar `pyspark` diretamente
#
# Caso já tenha as dependências em sua máquina, faça:

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark
#      -------------------------------------  447.9/455.4 MB 3.6 MB/s eta 0:00:03
#      -------------------------------------  448.2/455.4 MB 3.7 MB/s eta 0:00:02
#      -------------------------------------  448.5/455.4 MB 3.8 MB/s eta 0:00:02
#      -------------------------------------  448.8/455.4 MB 4.0 MB/s eta 0:00:02
#      -------------------------------------  449.1/455.4 MB 4.1 MB/s eta 0:00:02
#      -------------------------------------  449.4/455.4 MB 4.3 MB/s eta 0:00:02
#      -------------------------------------  449.6/455.4 MB 4.5 MB/s eta 0:00:02
#      -------------------------------------  450.0/455.4 MB 4.6 MB/s eta 0:00:02
#      -------------------------------------  450.3/455.4 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  450.6/455.4 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  450.9/455.4 MB 5.1 MB/s eta 0:00:01
#      -------------------------------------  451.2/455.4 MB 5.2 MB/s eta 0:00:01
#      -------------------------------------  451.6/455.4 MB 5.3 MB/s eta 0:00:01
#      -------------------------------------  451.9/455.4 MB 5.4 MB/s eta 0:00:01
#      -------------------------------------  452.1/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  452.4/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  452.6/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  452.8/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.0/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.2/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.4/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.5/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.7/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  453.9/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  454.1/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  454.2/455.4 MB 5.5 MB/s eta 0:00:01
#      -------------------------------------  454.4/455.4 MB 5.4 MB/s eta 0:00:01
#      -------------------------------------  454.5/455.4 MB 5.4 MB/s eta 0:00:01
#      -------------------------------------  454.7/455.4 MB 5.3 MB/s eta 0:00:01
#      -------------------------------------  454.8/455.4 MB 5.3 MB/s eta 0:00:01
#      -------------------------------------  454.9/455.4 MB 5.2 MB/s eta 0:00:01
#      -------------------------------------  454.9/455.4 MB 5.1 MB/s eta 0:00:01
#      -------------------------------------  455.0/455.4 MB 5.0 MB/s eta 0:00:01
#      -------------------------------------  455.1/455.4 MB 5.0 MB/s eta 0:00:01
#      -------------------------------------  455.2/455.4 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  455.2/455.4 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  455.2/455.4 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  455.3/455.4 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  455.3/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  455.4/455.4 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 455.4/455.4 MB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
#    ---------------------------------------- 0.0/203.0 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/203.0 kB 991.0 kB/s eta 0:00:01
#    -------------------- ------------------- 102.4/203.0 kB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 122.9/203.0 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 174.1/203.0 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 203.0/203.0 kB 1.0 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml): started
#   Building wheel for pyspark (pyproject.toml): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008747 sha256=531329090a38af503a9160ce96cb927c2edd664c83fa7822c44f42e8ea997a26
#   Stored in directory: c:\users\rafae\appdata\local\pip\cache\wheels\16\33\a9\f8bff354a182417214933df74dace2a34b02c3e5643e8fac74
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.9 pyspark-4.1.1
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Iniciando o Spark
#
# Vamos iniciar o ambiente Spark. Para isso vamos:
#
# 1) Criar um objeto de configuração do ambiente Spark. Nossa configuração será simples: vamos especificar que o nome da nossa aplicação Spark é "Minha aplicação", e que o *master node* é a máquina local, usando todos os *cores* disponíveis. Aplicações reais de Spark são configuradas de modo ligeiramente diferente: ao especificar o *master node* passamos uma URL real, com o endereço do nó gerente do *cluster* Spark.
#
# 2) Vamos criar um objeto do tipo `SparkContext` com essa configuração

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("MinhaAplicacao").getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# O `SparkContext` é a nossa porta de entrada para o cluster Spark, ele será a raiz de todas as nossas operações com o Spark.

# %%
sc
# Out:
# <SparkContext master=local[*] appName=MinhaAplicacao>

# %% [markdown]
# O link acima para a Spark UI provavelmente não funcionará porque ele se refere à porta 4040 interna do container (portanto a URL está com endereço interno). Porém fizemos o mapeamento da porta 4040 interna para a porta 4040 externa, logo você pode acessar o *dashboard* do Spark para monitorar seus *jobs* no endereço http://localhost:4040
#
# <center><img src="./img/spark_dashboard.png" width=800/></center>

# %% [markdown]
# Pronto, assim você vai conseguir testar seus programas com facilidade!

# %% [markdown]
# ## Trabalhando com RDDs
#
# Esse é o jeito "Apache raiz": Resilient Distributed Datasets (RDDs). Este é o principal objeto de processamento do Spark.
#
# Um RDD é criado à partir do objeto `SparkContext`. Por exemplo:

# %%
rdd = sc.parallelize([1, 2, 3, 4, 5])

# %% [markdown]
# Vamos recuperar dois elementos:

# %%
rdd.take(2)
# Out:
# [1, 2]

# %% [markdown]
# Um RDD também pode ser criado a partir de um dataset (claro!):

# %%
rdd = sc.textFile("data/memorias.txt")

# %% [markdown]
# Veja que o rdd pode ser particionado

# %%
print("Quantidade de partições: ", rdd.getNumPartitions())
# Out:
# Quantidade de partições:  2

# %% [markdown]
# Podemos imaginar um RDD como uma coleção de itens, similar a uma grande lista. O que vem em cada item depende do arquivo original de dados. Para arquivos de texto, cada linha é um item.
#
# https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.SparkContext.html e sobre os RDDs em https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.RDD.html

# %% [markdown]
# ### Açoes e Transformações

# %% [markdown]
# O objeto `rdd` é repleto de métodos para definir pipelines computacionais. Estes métodos se dividem em *actions* e *transformations*.
#
# *Transformations* são métodos que atuam no RDD e devolvem um "novo" RDD que está conectado ao RDD antigo. Por exemplo, vamos usar a *transformation* `map` para inverter a sequência de letras em cada linha:

# %%
def inverte_linha(linha):
    return linha[::-1]

rdd2 = rdd.map(inverte_linha)
rdd2
# Out:
# PythonRDD[17] at RDD at PythonRDD.scala:53

# %% [markdown]
# Se você consultar a Web UI do Spark (http://localhost:4040) vai ver que nada ainda aconteceu. Isto é assim porque o Spark é *lazy*: a computação só acontece quando um resultado de uma sequência de *transformations* é demandado por uma *action*.
#
# As *actions* são métodos que retornam dados para o seu programa. Por exemplo, a *action* `count` retorna o número de itens no RDD, e a *action* `take` permite coletar alguns itens no inicio do RDD, bem útil para debugar:

# %%
rdd.count()
# Out:
# 8843

# %% [markdown]
# Confira a Web UI e veja que agora temos um novo job completo!
#
# Vamos espiar as primeiras 20 linhas do documento original:

# %%
rdd.take(20)
# Out:
# ["Project Gutenberg's Memorias Postumas de Braz Cubas, by Machado de Assis",
#  '',
#  'This eBook is for the use of anyone anywhere in the United States and most',
#  'other parts of the world at no cost and with almost no restrictions',
#  'whatsoever.  You may copy it, give it away or re-use it under the terms of',
#  'the Project Gutenberg License included with this eBook or online at',
#  "www.gutenberg.org.  If you are not located in the United States, you'll have",
#  'to check the laws of the country where you are located before using this ebook.',
#  '',
#  'Title: Memorias Postumas de Braz Cubas',
#  '',
#  'Author: Machado de Assis',
#  '',
#  'Release Date: June 2, 2017 [EBook #54829]',
#  '',
#  'Language: Portuguese',
#  '',
#  '',
#  '*** START OF THIS PROJECT GUTENBERG EBOOK MEMORIAS POSTUMAS DE BRAZ CUBAS ***',
#  '']

# %% [markdown]
# E agora as 20 primeiras linhas após a inversão de linha:

# %%
rdd2.take(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 rdd2.take(20)
#
# NameError: name 'rdd2' is not defined

# %% [markdown]
# Vamos discutir algumas açoes e transformações uteis.

# %% [markdown]
# #### `map`
#
# A transformação `map` recebe uma função e aplica esta função a cada item do RDD. A função deve receber um item e retornar um unico item. Como exemplo temos o uso de `map` acima para inverter a ordem das letras de cada linha.
#
# Note que no `map`, o RDD resultante tem o mesmo numero de elementos do RDD original.
#
# **Exercicio 1**: Crie uma função chamada conta_letras que recebe um rdd e retorna o rdd transformado onde cada linha tenha a contagem de letras da linha recebida. Por exemplo, a linha "abacaxi" deve ser transformada em 7.

# %%
# resultado_esperado: [72, 0, 74, 67, 74, 67, 76, 79, 0, 38, 0, 24, 0, 41, 0, 20, 0, 0, 77, 0 ...

def conta_letras(rdd):
    resp = rdd.map(lambda x : len(x))
    return resp

conta_letras(rdd).take(20)
# Out:
# [72, 0, 74, 67, 74, 67, 76, 79, 0, 38, 0, 24, 0, 41, 0, 20, 0, 0, 77, 0]

# %% [markdown]
# **Atenção:** Caso tenha problemas em rederizar o botão de envio, **atualize a página**! Se o problema persistir, **teste em outros navegadorres**.

# %%
ia.sender(answer="conta_letras", task="spark", question="ex01", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar ex01', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# **Exercício 2**: Crie uma função chamada transforma_minusculas que recebe um rdd e retorna o rdd transformado onde cada linha tenha todas as letras em minúsculas. Por exemplo, a linha "AbaCaxi HOJE" deve ser transformada em "abacaxi hoje".

# %%
def transforma_minusculas(rdd):
    resp = rdd.map(lambda x : x.lower())
    return resp
    
transforma_minusculas(rdd).take(20)
# Out:
# ["project gutenberg's memorias postumas de braz cubas, by machado de assis",
#  '',
#  'this ebook is for the use of anyone anywhere in the united states and most',
#  'other parts of the world at no cost and with almost no restrictions',
#  'whatsoever.  you may copy it, give it away or re-use it under the terms of',
#  'the project gutenberg license included with this ebook or online at',
#  "www.gutenberg.org.  if you are not located in the united states, you'll have",
#  'to check the laws of the country where you are located before using this ebook.',
#  '',
#  'title: memorias postumas de braz cubas',
#  '',
#  'author: machado de assis',
#  '',
#  'release date: june 2, 2017 [ebook #54829]',
#  '',
#  'language: portuguese',
#  '',
#  '',
#  '*** start of this project gutenberg ebook memorias postumas de braz cubas ***',
#  '']

# %%
ia.sender(answer="transforma_minusculas", task="spark", question="ex02", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar ex02', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# #### `flatMap`
#
# Esta transformação é similar ao `map`, porém a função passada para o `flatMap` pode retornar zero ou mais itens. Estes itens então são concatenados e o RDD resultante acaba tendo um número de itens diferente do RDD original.
#
# Por exemplo: suponha que queremos gerar uma lista de palavras do documento. Podemos fazê-lo da seguinte forma:

# %%
def separa_palavras(linha):
    return linha.strip().split()

# %% [markdown]
# Observe o resultado da aplicação da função `separa_palavras` com `map`:

# %%
rdd_map = rdd.map(lambda x: x.lower()).map(separa_palavras)
rdd_map.take(30)
# Out:
# [['project',
#   "gutenberg's",
#   'memorias',
#   'postumas',
#   'de',
#   'braz',
#   'cubas,',
#   'by',
#   'machado',
#   'de',
#   'assis'],
#  [],
#  ['this',
#   'ebook',
#   'is',
#   'for',
#   'the',
#   'use',
#   'of',
#   'anyone',
#   'anywhere',
#   'in',
#   'the',
#   'united',
#   'states',
#   'and',
#   'most'],
#  ['other',
#   'parts',
#   'of',
#   'the',
#   'world',
#   'at',
#   'no',
#   'cost',
#   'and',
#   'with',
#   'almost',
#   'no',
#   'restrictions'],
#  ['whatsoever.',
#   'you',
#   'may',
#   'copy',
#   'it,',
#   'give',
#   'it',
#   'away',
#   'or',
#   're-use',
#   'it',
#   'under',
#   'the',
#   'terms',
#   'of'],
#  ['the',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'with',
#   'this',
#   'ebook',
#   'or',
#   'online',
#   'at'],
#  ['www.gutenberg.org.',
#   'if',
#   'you',
#   'are',
#   'not',
#   'located',
#   'in',
#   'the',
#   'united',
#   'states,',
#   "you'll",
#   'have'],
#  ['to',
#   'check',
#   'the',
#   'laws',
#   'of',
#   'the',
#   'country',
#   'where',
#   'you',
#   'are',
#   'located',
#   'before',
#   'using',
#   'this',
#   'ebook.'],
#  [],
#  ['title:', 'memorias', 'postumas', 'de', 'braz', 'cubas'],
#  [],
#  ['author:', 'machado', 'de', 'assis'],
#  [],
#  ['release', 'date:', 'june', '2,', '2017', '[ebook', '#54829]'],
#  [],
#  ['language:', 'portuguese'],
#  [],
#  [],
#  ['***',
#   'start',
#   'of',
#   'this',
#   'project',
#   'gutenberg',
#   'ebook',
#   'memorias',
#   'postumas',
#   'de',
#   'braz',
#   'cubas',
#   '***'],
#  [],
#  [],
#  [],
#  [],
#  ['produced',
#   'by',
#   'laura',
#   'natal',
#   'rodriguez',
#   '&',
#   'marc',
#   "d'hooghe",
#   'at',
#   'free'],
#  ['literature',
#   '(online',
#   'soon',
#   'in',
#   'an',
#   'extended',
#   'version,',
#   'also',
#   'linking'],
#  ['to', 'free', 'sources', 'for', 'education', 'worldwide', '...', "mooc's,"],
#  ['educational', 'materials,...)'],
#  [],
#  [],
#  []]

# %% [markdown]
# E o resultado com `flatMap`, que é o resultado desejado:

# %%
rdd_flatMap = rdd.map(lambda x: x.lower()).flatMap(separa_palavras)
rdd_flatMap.take(30)
# Out:
# ['project',
#  "gutenberg's",
#  'memorias',
#  'postumas',
#  'de',
#  'braz',
#  'cubas,',
#  'by',
#  'machado',
#  'de',
#  'assis',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the']

# %% [markdown]
# Veja a contagem de palavras no `rdd_flatMap`:

# %%
rdd_flatMap.count()
# Out:
# 64713

# %% [markdown]
# Compare com o numero de itens no RDD original:

# %%
rdd.count()
# Out:
# 8843

# %% [markdown]
# **Exercício 3**: Crie uma função chamada gera_bigramas que recebe um rdd e retorna o rdd transformado onde cada linha contém uma **tupla** com um *bigrama*: sequências de duas palavras consecutivas.
#
# Gere cada bigrama como uma **tupla** (p[i], p[i+1]).
#
# Sua função deve utilizar o comando `flatMap`. Para esse exercício é permitido utilizar um comando for dentro do flatmap. Por que isso não prejudica a performance?
#
# Além disso, teremos um pequeno problema nos bigramas - que problema é esse?

# %%
def gera_bigramas(rdd):
    resp = rdd.map(lambda y: y.split()).flatMap(lambda x: [(x[i].lower(), x[i+1].lower()) for i in range(len(x)-1)])
    return resp
    
rdd_bigramas = gera_bigramas(rdd)
rdd_bigramas.take(20)
# Out:
# [('project', "gutenberg's"),
#  ("gutenberg's", 'memorias'),
#  ('memorias', 'postumas'),
#  ('postumas', 'de'),
#  ('de', 'braz'),
#  ('braz', 'cubas,'),
#  ('cubas,', 'by'),
#  ('by', 'machado'),
#  ('machado', 'de'),
#  ('de', 'assis'),
#  ('this', 'ebook'),
#  ('ebook', 'is'),
#  ('is', 'for'),
#  ('for', 'the'),
#  ('the', 'use'),
#  ('use', 'of'),
#  ('of', 'anyone'),
#  ('anyone', 'anywhere'),
#  ('anywhere', 'in'),
#  ('in', 'the')]

# %%
ia.sender(answer="gera_bigramas", task="spark", question="ex03", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar ex03', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# O problema é que bigramas que cruzam linhas não serão contabilizados.

# %% [markdown]
# #### `filter`
#
# A transformação `filter` recebe uma função que recebe um item e retorna True se o item deve ser mantido, e False se deve ser ignorado. Por exemplo, suponha que temos uma lista de palavras proibidas e queremos manter apenas as palavras permitidas da nossa lista de palavras em `rdd_flatMap`:

# %%
rdd_flatMap.take(30)

# %%
def eh_palavra_permitida(palavra):
    palavras_proibidas = set(["Braz", "Assis"])
    return palavra not in palavras_proibidas

rdd_limpo = rdd_flatMap.filter(eh_palavra_permitida)
rdd_limpo.take(30)

# %% [markdown]
# #### `reduce`
#
# A *action* `reduce` apresenta o mesmo comportamento da operação `reduce` da biblioteca `functools` do Python. Ela recebe uma função de dois argumentos que retorna apenas um valor. O comportamento de `reduce` é aplicar esta função aos vários elementos do RDD de modo sucessivo, visando "reduzir" o RDD inteiro a um único valor, que é então retornado para o programa principal.
#
# Por exemplo, suponha que desejamos calcular a soma dos comprimentos de palavras. Podemos fazer o seguinte:

# %%
rdd_flatMap.map(lambda x: len(x)).reduce(lambda x, y: x + y)

# %% [markdown]
# Note que como `reduce` é uma *action*, temos um resultado concreto.
#
# **Exercício 4**: Crie uma função chamada maior_palindromo que recebe um rdd com o texto e retorna a maior palavra palíndroma do texto.

# %%
def maior_palindromo(rdd):
    palavras = rdd.flatMap(lambda x: x.split())
    palindromos = palavras.filter(lambda x: x == x[::-1])
    resp = palindromos.reduce(lambda x, y: x if len(x) > len(y) else y)
    return resp

# %%
ia.sender(answer="maior_palindromo", task="spark", question="ex04", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar ex04', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# ### Pares chave-valor
#
# Sempre que o RDD consistir em itens que sejam tuplas de dois elementos, Spark vai considerar que temos um par chave-valor por item. Isso nos permite realizar agregações por chave, abrindo a possibilidade de coletar dados agregados mais interessantes.
#
# #### `reduceByKey`
# Para essa tarefa, a transformação mais importante é a `reduceByKey`. Esta operação realiza uma agregação por chave (gerando uma lista de valores para aquela chave), e realiza uma redução da lista dos valores associados à chave.
#
# Por exemplo, o *hello world* do Spark: o conta-palavras:

# %%
rdd_flatMap \
    .map(lambda x: (x, 1)) \
    .reduceByKey(lambda x, y: x + y) \
    .takeOrdered(10, lambda x: -x[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 rdd_flatMap \
#       2     .map(lambda x: (x, 1)) \
#       3     .reduceByKey(lambda x, y: x + y) \
#       4     .takeOrdered(10, lambda x: -x[1])
#
# NameError: name 'rdd_flatMap' is not defined

# %% [markdown]
# **Exercício 5**: Crie uma função chamada conta_bigramas que recebe um rdd com as tuplas de bigramas e retorna pares chave e valor dos 10 bigramas mais populares.
#
# **Atenção:** Apesar da resposta aparecer como se fossem listas, os elementos apresentados são tuplas em python.

# %%
def conta_bigramas(rdd_bigramas):
    tuplas = rdd_bigramas.map(lambda x: (x, 1))
    cont = tuplas.reduceByKey(lambda x, y: x + y)
    resp = cont.takeOrdered(10, lambda x: -x[1])
    return resp

conta_bigramas(gera_bigramas(rdd))
# Out:
# [(('.', '.'), 159),
#  (('de', 'um'), 148),
#  (('que', 'a'), 133),
#  (('que', 'o'), 125),
#  (('que', 'não'), 117),
#  (('que', 'me'), 116),
#  (('o', 'que'), 111),
#  (('e', 'a'), 107),
#  (('que', 'eu'), 107),
#  (('de', 'uma'), 100)]

# %%
ia.sender(answer="conta_bigramas", task="spark", question="ex05", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar ex05', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# #### `join`
#
# A transformação `join` realiza o *inner join* de dois RDDs. Por exemplo:

# %%
rdd_a = sc.parallelize([("a", 10), ("b", 20), ("b", 30)])
rdd_b = sc.parallelize([("a", "banana"), ("a", "abacate"), ("b", "chuchu"), ("b", "tomate")])
rdd_c = rdd_a.join(rdd_b)

rdd_c.collect()
# Out:
# [('b', (20, 'chuchu')),
#  ('b', (20, 'tomate')),
#  ('b', (30, 'chuchu')),
#  ('b', (30, 'tomate')),
#  ('a', (10, 'banana')),
#  ('a', (10, 'abacate'))]

# %% [markdown]
# **Desafio 1**: Crie uma função chamada desafio1 que recebe um rdd e o transforma de modo que para cada bigrama, temos a seguinte informação:
#
# (bigrama, contagem_bigrama, contagem_palavra_1, contagem_palavra_2)
#
# **Atenção:** Apesar da resposta aparecer como se fossem listas, os elementos apresentados são tuplas em python.

# %%
def desafio1(rdd):
    def gera_bigramas(rdd):
        resp = rdd.map(lambda y: y.split()).flatMap(lambda x: [(x[i].lower(), x[i+1].lower()) for i in range(len(x)-1)])
        return resp
    
    def conta_bigramas(rdd_bigramas):
        tuplas = rdd_bigramas.map(lambda x: (x, 1))
        cont = tuplas.reduceByKey(lambda x, y: x + y)
        return cont
    bigramas = conta_bigramas(gera_bigramas(rdd))
    palavras = rdd.flatMap(lambda linha: linha.lower().split()).map(lambda p: (p, 1)).reduceByKey(lambda a, b: a + b)
    passo1 = bigramas.map(lambda x: (x[0][0], (x[0], x[1]))).join(palavras)
    passo2 = passo1.map(lambda x: (x[1][0][0][1], (x[1][0][0], x[1][0][1], x[1][1]))).join(palavras)
    resp = passo2.map(lambda x: (x[1][0][0], x[1][0][1], x[1][0][2], x[1][1]))
    return resp
    
desafio1(rdd).take(10)
# Out:
# [(('by', 'e-mail)'), 1, 28, 1),
#  (('use', 'part'), 1, 11, 4),
#  (('any', 'part'), 2, 35, 4),
#  (('a', 'part'), 1, 2593, 4),
#  (('use', 'and'), 2, 11, 69),
#  (('of', 'and'), 1, 122, 69),
#  (('using', 'and'), 1, 6, 69),
#  (('this', 'and'), 1, 49, 69),
#  (('gutenberg-tm', 'and'), 1, 54, 69),
#  (('ebooks,', 'and'), 1, 2, 69)]

# %%
ia.sender(answer="desafio1", task="spark", question="desafio1", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar desafio1', style=ButtonStyle()), Output()), _dom_classes=('wi…

# %% [markdown]
# **Desafio 2**: Faça uma função chamada desafio2 que recebe um RDD no formato retornado pela função desafio1 e constrói um RDD com a seguinte informação:
#
# `(bigrama, (contagem_bigrama) /((contagem_palavra_1 + K) * (contagem_palavra_2 + K)))`
#
# para K = 10
#
# Por fim, retorne os 15 bigramas com maior valor associado.

# %%
def desafio2(rdd_d1):
    K = 10

    return (rdd_d1.map(lambda x: (x[0],x[1] / ((x[2] + K) * (x[3] + K)))).takeOrdered(15, key=lambda x: -x[1]))

desafio2(desafio1(rdd))
# Out:
# [(('set', 'forth'), 0.024691358024691357),
#  (('arma', 'virumque'), 0.020833333333333332),
#  (('qui', "l'eut"), 0.02040816326530612),
#  (('memorias', 'postumas'), 0.0196078431372549),
#  (('web', 'site'), 0.01904761904761905),
#  (('literary', 'archive'), 0.01890359168241966),
#  (('virumque', 'cano'), 0.017857142857142856),
#  (('memórias', 'pósthumas'), 0.01775147928994083),
#  (('information', 'about'), 0.016339869281045753),
#  (('archive', 'foundation'), 0.016304347826086956),
#  (('phrase', '"project'), 0.014814814814814815),
#  (('"project', 'gutenberg"'), 0.014285714285714285),
#  (('gutenberg', 'literary'), 0.014066496163682864),
#  (('laura', 'natal'), 0.013888888888888888),
#  (('intellectual', 'property'), 0.013888888888888888)]

# %%
ia.sender(answer="desafio2", task="spark", question="desafio2", answer_type="pycode")
# Out:
# interactive(children=(Button(description='Enviar desafio2', style=ButtonStyle()), Output()), _dom_classes=('wi…

# %% [markdown]
# ## Gabarito

# %% [markdown]
# **<div id="gab_ex3">**Exercício 3**</div>**
# <div class="alert alert-warning">
#
# ```python
# def gera_bigramas(rdd):
#     return rdd.map(lambda x: x.lower()) \
#         .map(lambda x: x.split()) \
#         .flatMap(lambda x: [(x[i], x[i+1]) for i in range(len(x)-1)])
# ```
#
# </div>

# %% [markdown]
# **<div id="gab_ex4">**Exercício 5**</div>**
# <div class="alert alert-warning">
#
# ```python
# def conta_bigramas(rdd_bigramas):
#     rdd_conta_bigramas = rdd_bigramas.map(lambda x: (x, 1)).reduceByKey(lambda x, y: x + y)
#     return rdd_conta_bigramas.takeOrdered(10, lambda x: -x[1])
# ```
#
# </div>
